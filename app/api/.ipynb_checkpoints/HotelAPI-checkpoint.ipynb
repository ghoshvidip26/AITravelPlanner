# %%
import requests

# %%
def obtainAccessToken(): 
    url = "https://test.api.amadeus.com/v1/security/oauth2/token"
    payload = {
        "grant_type": "client_credentials",
        "client_id": "RA57nHwp1gG2QPegkGPqHnC2zhmE09CA",          
        "client_secret": "qCUjQXP9tMOQAKk5"   
    }
    headers = {"Content-Type": "application/x-www-form-urlencoded"}
    response = requests.post(url, data=payload, headers=headers).json()
    return response.get("access_token")

# %%
def hotelAPI(cityCode): 
    url = f"https://test.api.amadeus.com/v1/reference-data/locations/hotels/by-city?cityCode={cityCode}"
    accessToken = obtainAccessToken()
    headers = {"Authorization": f"Bearer {accessToken}"}
    response = requests.get(url, headers=headers).json()
    return response

# %%
hotel = hotelAPI("DEL")

for hotel in hotel.get("data", []):
    name = hotel.get("name")
    print(name)
# Out:
# VIVANTA BY TAJ GURGAON
# CROWNE PLAZA NEW DELHI OKHLA
# CITY PREMIER
# THE SURYAA SUMMIT HOTELS
# MAIDENS HOTEL
# HOTEL STAR ROCKS
# VIVANTA BY TAJ DWARKA
# GINGER EAST DELHI
# OPTUS HOMETEL BHIWADI
# FORTUNE SELECT EXCALIBUR
# HOTEL GRD INN
# GOLDEN TULIP CHATTARPUR NEW DELHI
# JW MARRIOTT HOTEL NEW DELHI AEROCITY
# HOTEL SUNRISE VILLA
# FLORENCE INN
# VEDAS HERITAGE
# HOTEL ROYAL CASTLE GRAND
# COUNTRY INN GURGAON SOHNA ROAD
# PARKLAND GRAND
# RADISSON BLU PLAZA DELHI
# JUSTA THE RESIDENCE
# HOTEL BAMYAN
# WELCOMHOTEL DWARKA NEW DELHI
# COURTYARD GURGAON MARRIOTT
# RADISSON BLU HOTEL GHAZIABAD
# CITRUS HOTELS GURGAON CENTRE
# HOTEL PITRASHISH PRIDE
# BEST WESTERN RESORT COUNTRY CLUB
# TIVOLICITITEL
# CLARKS INN SUITES EARLIER VITS DELHI NCR
# VANSON VILLA
# INDRAPRASTHA HOTEL
# VIVANTA BY TAJ AMBASSADOR
# HOTEL GULMOHAR VILLA-GURGAON
# RED FOX HOTEL AEROCITY
# CROWNE PLAZA MAYUR VIHAR NOIDA
# CROWNE PLAZA GURGAON
# HOTEL ALPINA
# HOTEL OMNI
# THE PALMS TOWN AND COUNTRY CLUB
# SARTHAK PALACE
# IBIS GURGAON
# FORT UNCHAGAON GARHMUKTESHWAR
# THE TAJ MAHAL HOTEL
# THE UPPAL - AN ECOTEL HOTEL
# TOPAZ
# TAJ PALACE HOTEL NEW DELHI
# COMFORT INN ANNEHA
# CROWNE PLAZA GREATER NOIDA
# VIVA DESTINATIONS
# CLARION COLLECTION
# UNIVERSE INN
# RADISSON BLU HOTEL NOIDA
# HOLIDAY INN NEW DELHI INTL ARPT
# RADISSON BLU HTL GREATER NOIDA
# ROCKLAND PANCHSHEEL ENCLAVE
# GRAND NEW DELHI
# HOTEL THE ROYAL PLAZA
# HERITAGE VILLAGE RESORT AND SPA
# HOTEL MAAN K
# ROYAL RETREAT
# HOTEL B CONTINENTAL
# HOTEL PARK RESIDENCY
# THE SARISKA PALACE
# FORTUNE INN GRAZIA GHAZIABAD
# HOTEL GRAND GODWIN
# LEMON TREE PREMIER, DELHI AEROCITY
# LEMON TREE PREMIER - DELHI AEROCITY
# ROCKLAND C R PARK
# ROCKLAND CR PARK
# ROUSHA INN
# TAVISHA VILLA
# ROYAL RESIDENCY
# JUSTA THE RESIDENCE GK DELHI
# EATON SMART NEW DELHI AIRPORT
# COUNTRY INN SUITES SATBARI
# KINGSTON
