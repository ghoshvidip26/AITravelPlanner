# %%
from newsapi import NewsApiClient
import requests
import datetime

# %%
print(x.text)
# Out:
# {"status":"ok","totalResults":638,"articles":[{"source":{"id":null,"name":"DW (English)"},"author":"Murali Krishnan","title":"Kashmir attack presents security dilemma for India","description":"At least 26 tourists were killed in India-administered Kashmir, marking a significant escalation in violence that has dented the Indian government's narrative of stability in the region. Indian officials on Wednesday continued to work out a response to a dead…","url":"https://www.dw.com/en/kashmir-attack-presents-security-dilemma-for-india/a-72321198","urlToImage":"https://static.dw.com/image/72319411_6.jpg","publishedAt":"2025-04-23T13:52:00Z","content":"Indian officials on Wednesday continued to work out a response to a deadly mass shooting at a popular tourist location in India-administered Kashmir, which killed at least 26 people and wounded 17 ot… [+7786 chars]"},{"source":{"id":null,"name":"DW (English)"},"author":"Murali Krishnan","title":"Attack in disputed Kashmir poses security dilemma for India","description":"At least 26 tourists were killed in India-administered Kashmir, marking a significant escalation in violence that has dented the Indian government's narrative of stability in the region.","url":"https://www.dw.com/en/attack-in-disputed-kashmir-poses-security-dilemma-for-india/a-72321198","urlToImage":"https://static.dw.com/image/72319411_6.jpg","publishedAt":"2025-04-23T13:52:00Z","content":"Indian officials on Wednesday continued to work out a response to a deadly mass shooting at a popular tourist location in India-administered Kashmir that killed at least 26 people and wounded 17 othe… [+7851 chars]"},{"source":{"id":null,"name":"DW (English)"},"author":"Murali Krishnan","title":"Kashmir attack: a tragedy and a security 'setback' for India","description":"At least 26 tourists were killed in India-administered Kashmir, marking a significant escalation in violence that has dented the Indian government's narrative of stability in the region.","url":"https://www.dw.com/en/kashmir-attack-a-tragedy-and-a-security-setback-for-india/a-72321198","urlToImage":"https://static.dw.com/image/72319411_6.jpg","publishedAt":"2025-04-23T13:52:00Z","content":"Indian officials on Wednesday continued to work out a response to a deadly mass shooting at a popular tourist location in India-administered Kashmir that killed at least 26 people and wounded 17 othe… [+7851 chars]"},{"source":{"id":null,"name":"Aajtak.in"},"author":"aajtak.in","title":"Jammu-Kashmir टूर रद्द कर रहे लोग, टूरिज्म इंडस्ट्री को झटका","description":"22 अप्रैल को जम्मू कश्मीर के पहलगाम में हुए आतंकी हमले से लोग दहशत में हैं..आलम ये है कि बड़ी संख्या में लोगों ने जम्मू-कश्मीर के टूर रद्द कर दिए हैं... खासकर पश्चिम बंगाल, बिहार और दूसरे पूर्वी राज्यों के यात्री इस हमले के बाद डर की वजह से अपनी यात्रा रद्द क…","url":"https://www.aajtak.in/short-videos/video/pahalgam-terror-attack-leads-to-mass-cancellations-kashmir-tourism-impacted-2224087-2025-04-23","urlToImage":"https://akm-img-a-in.tosshub.com/aajtak/images/video/202504/6808eb412d8e4-tourism-industry-effect-232931804-16x9.jpg","publishedAt":"2025-04-23T13:30:22Z","content":"Please rotate your device\r\n . ."},{"source":{"id":null,"name":"NDTV News"},"author":"Rohit Paul","title":"\"Blood, Water...\": Ex Diplomat Calls For Halting Indus Water Treaty With Pak","description":"Calling for a strong response after the terrorist attack in Jammu and Kashmir&#039;s Pahalgam, in which 26 people were killed, former foreign secretary Kanwal Sibal has called for the indefinite suspension of the Indus Waters Treaty with Pakistan.","url":"https://www.ndtv.com/india-news/pahalgam-terror-attack-j-8237302","urlToImage":"https://c.ndtvimg.com/2025-04/6gd44i68_kanwal-sibal_625x300_23_April_25.jpg?im=FeatureCrop,algorithm=dnn,width=1200,height=738","publishedAt":"2025-04-23T13:26:13Z","content":"Calling for a strong response after the terrorist attack in Jammu and Kashmir's Pahalgam, in which 26 people were killed, former foreign secretary ...

# %%
def fetchNews(q,date): 
    date_entry = input('Enter a date in YYYY-MM-DD format')
    year, month, day = map(int, date_entry.split('-'))
    date = datetime.date(year, month, day)
    url=f"https://newsapi.org/v2/everything?q={q}&from={date}&sortBy=publishedAt&apiKey=8f5255313e8b40eaaaec8567a3e3788b"
    x = requests.get(url).json()
    return x

# %%
r = fetchNews("Gangtok","2025-04-15")
# Out:
# Enter a date in YYYY-MM-DD format 2025-04-01

# %%
print(r)
# Out:
# {'status': 'ok', 'totalResults': 31, 'articles': [{'source': {'id': None, 'name': 'Skift'}, 'author': 'Bulbul Dhawan', 'title': 'India Wants 1 Million Cruise Tourists\xa0by 2029', 'description': 'Cruise tourism in India has long had a loyal following, but it’s the growing integration with the MICE (meetings, incentives, conferences, and exhibitions) segment that’s giving it an extra push. -Bulbul Dhawan', 'url': 'http://skift.com/2025/04/23/india-wants-1-million-cruise-tourists-by-2029/', 'urlToImage': 'https://skift.com/wp-content/uploads/2025/04/Kerala-Houseboat-pexels-benhur-emmanuel-83498627-11828727.jpg', 'publishedAt': '2025-04-24T03:00:00Z', 'content': 'The Indian government is focusing on growing the burgeoning cruise tourism sector in the country. For this, it is looking at coastal as well as river cruise tourism through the Cruise Bharat Mission … [+8906 chars]'}, {'source': {'id': None, 'name': 'Skift'}, 'author': 'Bulbul Dhawan', 'title': "India's Hotel Boom Expands into Untapped Markets", 'description': 'Post-Covid, hotel chains in India were playing catch up with unprecedented surge in demand. That done, the industry is back to anticipatory expansion, but in unexplored regions this time. -Bulbul Dhawan', 'url': 'http://skift.com/2025/04/22/indias-hotel-boom-expands-into-untapped-markets/', 'urlToImage': 'https://skift.com/wp-content/uploads/2025/04/pexels-harsh-14916663.jpg', 'publishedAt': '2025-04-23T03:59:26Z', 'content': 'Skift reported last year that the hospitality boom in India was being driven by smaller cities. Now the industry is going even further afield.\xa0\r\nThis week, IHG Hotels &amp; Resorts signed a Holiday I… [+4394 chars]'}, {'source': {'id': None, 'name': 'Thehillstimes.in'}, 'author': 'The Hills Times', 'title': 'Rajya Sabha Panel Visits Sikkim to Review Subordinate Legislation', 'description': 'HT Digital GANGTOK, APR 22: A parliamentary committee from the Rajya Sabha has begun a six-day visit to Sikkim to assess the implementation of subordinate legislation in the state. Led by Member of Parliament Milind Deora, the delegation arrived in Gangtok on…', 'url': 'https://thehillstimes.in/northeast/rajya-sabha-panel-visits-sikkim-to-review-subordinate-legislation', 'urlToImage': 'https://thehillstimes.in/wp-content/uploads/2025/04/WhatsApp-Image-2025-04-22-at-1.53.42-PM.jpeg', 'publishedAt': '2025-04-22T08:24:49Z', 'content': 'HT Digital\r\nGANGTOK, APR 22: A parliamentary committee from the Rajya Sabha has begun a six-day visit to Sikkim to assess the implementation of subordinate legislation in the state.\r\nLed by Member of… [+1211 chars]'}, {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'}, 'author': 'Anumeha Chaturvedi and Prachi Verma', 'title': 'Summer travel: Soaring heat & affluence push Indians to book pricier, visa-free vacations abroad', 'description': 'As temperatures rise, Indians are increasingly booking summer vacations, both domestically and internationally, despite rising costs. Travel experts anticipate a 10-15% increase in package prices due to high demand and limited availability. Visa-free or easy-…', 'url': 'https://economictimes.indiatimes.com/industry/services/travel/summer-travel-soaring-heat-affluence-push-indians-to-book-pricier-visa-free-vacations-abroad/articleshow/120440943.cms', 'urlToImage': 'https://img.etimg.com/thumb/msid-120441146,width-1200,height-630,imgsize-89422,overlay-economictimes/articleshow.jpg', 'publishedAt': '2025-04-20T00:00:00Z', 'content': 'New Delhi: As the mercury inches up a notch each passing day, an increasing number of Indians are booking cool vacations--often beyond home shores--to beat the oppressive heat, undeterred by airline … [+4305 chars]'}, {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'}, 'author': 'Sneha Kulkarni', 'title': 'Saturday bank holiday today: Are banks open or closed today on April 19, 2025?', 'description': 'Following Good Friday, banks customers may be wondering if bank bran ...
